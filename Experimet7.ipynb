# %% [markdown]
# <a href="https://colab.research.google.com/github/SjScripter/AIML_EXPERIMENT_LAB/blob/main/Experimet7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DATE: 01.11.2024
#
# Experiment 7:
# Implement feature scaling and one hot encoding data preprocessing techniques on the dataset imported in lab 4 or any other dataset.

# %% [markdown]
# >>For importing pandas and sklearn and also uploading the CSV files so that we can start using the feature scaling

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-54c49a36-e98e-4806-baf4-5d6a2bdc3bfb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-54c49a36-e98e-4806-baf4-5d6a2bdc3bfb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io

# %%
df = pd.read_csv(io.BytesIO(uploaded['customers-100.csv']))

# %% [markdown]
# >>For displaying the initial information for the CSV file

# %%
df.head()
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %% [markdown]
# >>Seprating the Numerical and the Categorical Features

# %%
numerical_features = df.select_dtypes(include=['int64', 'float64']).columns

# %%
categorical_features = df.select_dtypes(include=['object']).columns

# %% [markdown]
# >>Standardardization

# %%
scaler = StandardScaler()
df[numerical_features] = scaler.fit_transform(df[numerical_features])

# %% [markdown]
# >>Scaling the Numerical Features

# %%
df[numerical_features].head()
# Out:
#       Index
# 0 -1.714816
# 1 -1.680173
# 2 -1.645531
# 3 -1.610888
# 4 -1.576245

# %% [markdown]
# >>One-Hot Encoding for Categorical Variables

# %%
df = pd.get_dummies(df, columns=categorical_features, drop_first=True)

# %%
df.head()
# Out:
#       Index  Customer Id_03A1E62ADdeb31c  Customer Id_053d585Ab6b3159  \
# 0 -1.714816                        False                        False
# 1 -1.680173                        False                        False
# 2 -1.645531                        False                        False
# 3 -1.610888                        False                        False
# 4 -1.576245                        False                         True
#
#    Customer Id_09D7D7C8Fe09aea  Customer Id_0F60FF3DdCd7aB0  \
# 0                        False                        False
# 1                        False                        False
# 2                        False                        False
# 3                        False                        False
# 4                        False                        False
#
#    Customer Id_0e04AFde9f225dE  Customer Id_17aD8e2dB3df03D  \
# 0                        False                        False
# ...
